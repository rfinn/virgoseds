# %% [markdown]
# # Correcting for Galactic Extinction
#
# * Cardelli+1989 Extinction Law https://ui.adsabs.harvard.edu/abs/1989ApJ...345..245C/abstract
#
# * for GALEX:

# %%
import os
os.chdir('/home/rfinn/research/Virgo/tables-north/v2/')
# %run ~/github/Virgo/programs/write_subtables_v2.py --version v2 --north
# Out:
# Running on Rose's computer
# outdir =  /home/rfinn/research/Virgo/tables-north/v2/

# %%
c.runall()
# Out:
# number of galaxies with D25 measurement = 5732 (0.85%)
# number of galaxies using NSA V1 Petro TH90 = 470 (0.07%)
# number of galaxies using NSA V1 Petro TH90 = 56 (0.01%)
# number of galaxies using A100 sdss Petro TH90 = 262 (0.04%)
# number of galaxies with no size measurement = 260 (0.04%)
# adjusting radius for  --  galaxies based on legacy images
# number of galaxies with updated values of radius =  146
# could not match galaxy
#   VFID       RA       DEC      vr   radius radius_flag         objname         NSAID NSAIDV0 AGC          NEDname           HLflag NSAflag NSAV0flag A100flag COflag HAflag HAobsflag Z0MGSflag Steerflag unwiseflag               prefix                 name   confirm_name by-eye id updated in by_eye keep? fix_rad recenter outside_legacy    Comment     RA_new DEC_new radius_new
# ...

# %%
c.co
# Out:
# <Table length=1>
#  col0  col1  col2  col3  col4  col5 ... col1340 col1341 col1342 col1343 col1344
# uint8 uint8 uint8 uint8 uint8 uint8 ...  uint8   uint8   uint8   uint8   uint8
# ----- ----- ----- ----- ----- ----- ... ------- ------- ------- ------- -------
#    60    63   120   109   108    32 ...      66      76      69      62      10

# %%
cofile = homedir+'/research/Virgo/gianluca_input_tables/for_vf_gastable.fits'
cotab = Table(fits.getdata(cofile))

# %%
cotab
# Out:
# <Table length=1>
#  col0  col1  col2  col3  col4  col5 ... col1340 col1341 col1342 col1343 col1344
# uint8 uint8 uint8 uint8 uint8 uint8 ...  uint8   uint8   uint8   uint8   uint8
# ----- ----- ----- ----- ----- ----- ... ------- ------- ------- ------- -------
#    60    63   120   109   108    32 ...      66      76      69      62      10

# %% [markdown]
# I can't read in gianluca's table with astropy.
#
# I opened it in topcat and saved as a fits_basic.
#
# tryting to read it again

# %%
cofile = homedir+'/research/Virgo/gianluca_input_tables/for_vf_gastable_fitsbasic.fits'
cotab = Table(fits.getdata(cofile))

# %%
cotab
# Out:
# <Table length=547>
#         RA                DEC         ... MH2_to_MHI_err_down
#      float64            float64       ...       float64
# ------------------ ------------------ ... --------------------
#         153.202375  43.14552777777778 ...                  nan
# 197.14279166666665 21.049972222222223 ... 0.008655657131548488
# 217.50766666666667  3.772861111111111 ... 0.004942906998845658
# 217.86333333333334 3.0090833333333333 ...  0.01151409302912066
# 220.74166666666667 4.8894722222222216 ...  0.01799824315295856
# 223.26166666666666  3.296111111111111 ...      0.0364371115209
#         223.271875 3.3317777777777775 ... 0.011976268908774604
# 239.63475000000003 17.441472222222224 ...  0.02174273867415867
#         243.625625  62.53669444444444 ... 0.012565263479046542
# 124.22687499999999            24.1766 ...                 -1.0
#                ...                ... ...                  ...
#        351.6656208         25.0801111 ...                 -1.0
# ...

# %% [markdown]
# That works!  Not sure why, but I'm not asking more questions...

# %%
os.chdir('/home/rfinn/research/Virgo/tables-north/v2/')
# %run ~/github/Virgo/programs/write_subtables_v2.py --version v2 --north
# Out:
# outdir =  /home/rfinn/research/Virgo/tables-north/v2/

# %%
c.runall()
# Out:
# number of galaxies with D25 measurement = 5732 (0.85%)
# number of galaxies using NSA V1 Petro TH90 = 470 (0.07%)
# number of galaxies using NSA V1 Petro TH90 = 56 (0.01%)
# number of galaxies using A100 sdss Petro TH90 = 262 (0.04%)
# number of galaxies with no size measurement = 260 (0.04%)
# adjusting radius for  --  galaxies based on legacy images
# number of galaxies with updated values of radius =  146
# could not match galaxy
#   VFID       RA       DEC      vr   radius radius_flag         objname         NSAID NSAIDV0 AGC          NEDname           HLflag NSAflag NSAV0flag A100flag COflag HAflag HAobsflag Z0MGSflag Steerflag unwiseflag               prefix                 name   confirm_name by-eye id updated in by_eye keep? fix_rad recenter outside_legacy    Comment     RA_new DEC_new radius_new
# ...

# %%
c.get_extinction()
# Out:
# length of etab =  6780 6780

# %%
# !ls *extinction*
# Out:
# vf_v2_extinction.fits
