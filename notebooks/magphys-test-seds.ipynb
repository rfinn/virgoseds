# %% [markdown]
# # This notebook is working with test sample of 200 galaxies
#
# * see maphys-full-sample for the results for the full sample

# %%
import os
import numpy as np

# %%
# Filter_wavelength
wavelengths = np.array([0.3512,
     0.4601,
     0.5379,
     0.6516,
     0.8658,
     0.9056,
     1.2409,
     2.1656,
     3.5634,
     4.5110,
     5.7593,
     7.9595,
    16.0439,
    23.6747,
    71.5462,
   107.4250,
   166.1734,
   250.9415,
   354.2736,
   509.4689])

# %%
os.chdir("/home/rfinn/software/magphys-damien/")

# %%
# %run ~/github/virgoseds/python/sedFunctions.py

# %%
s = magphys_sed("2326",wavelengths)
s.plot_sed()
s.plot_histograms()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-4acb96c04e11> in <module>
#       1 s = magphys_sed("2326",wavelengths)
# ----> 2 s.plot_sed()
#       3 s.plot_histograms()
#
# ~/github/virgoseds/python/sedFunctions.py in plot_sed(self, plot_unattenuated)
#     130         resid_ax = fig.add_subplot(gs[1,0],sharex=ax)
#     131
# --> 132         self.read_sed_file(self.sed_file,ax1=ax,plot_unattenuated=plot_unattenuated)
#     133         self.read_fit_file(self.fit_file,ax1=ax,ax2=resid_ax)
#     134
#
# ~/github/virgoseds/python/sedFunctions.py in read_sed_file(self, sed_file, ax1, plot_unattenuated)
#     187         plt.savefig(outfile)
#     188     def read_sed_file(self,sed_file,ax1=None,plot_unattenuated=True):
# --> 189         self.sed = Table.read(sed_file,data_start=2,format='ascii')
#     190         self.wave = np.array(self.sed['col1'],'d')
# ...

# %%
s = magphys_sed("4170",wavelengths)
s.plot_sed()
s.plot_histograms()
# Out:
# /home/rfinn/github/virgoseds/python/sedFunctions.py:229: RuntimeWarning: invalid value encountered in log10
#   L_flux=np.log10((1.+z)*flux*frequency) # log of nu L_nu
# /home/rfinn/github/virgoseds/python/sedFunctions.py:231: RuntimeWarning: invalid value encountered in log10
#   L_eflux_lo=np.log10((1.+z)*flux*frequency)-np.log10((1.+z)*flux*frequency-e_flux*(1.+z)*frequency)
# /home/rfinn/github/virgoseds/python/sedFunctions.py:232: RuntimeWarning: invalid value encountered in log10
#   L_eflux_hi=-np.log10((1.+z)*flux*frequency)+np.log10((1.+z)*flux*frequency+e_flux*(1.+z)*frequency)

# %%
s = magphys_sed("4732",wavelengths)
s.plot_sed()
s.plot_histograms()
# Out:
# /home/rfinn/github/virgoseds/python/sedFunctions.py:229: RuntimeWarning: divide by zero encountered in log10
#   L_flux=np.log10((1.+z)*flux*frequency) # log of nu L_nu
# /home/rfinn/github/virgoseds/python/sedFunctions.py:229: RuntimeWarning: invalid value encountered in log10
#   L_flux=np.log10((1.+z)*flux*frequency) # log of nu L_nu
# /home/rfinn/github/virgoseds/python/sedFunctions.py:231: RuntimeWarning: divide by zero encountered in log10
#   L_eflux_lo=np.log10((1.+z)*flux*frequency)-np.log10((1.+z)*flux*frequency-e_flux*(1.+z)*frequency)
# /home/rfinn/github/virgoseds/python/sedFunctions.py:231: RuntimeWarning: invalid value encountered in log10
#   L_eflux_lo=np.log10((1.+z)*flux*frequency)-np.log10((1.+z)*flux*frequency-e_flux*(1.+z)*frequency)
# /home/rfinn/github/virgoseds/python/sedFunctions.py:231: RuntimeWarning: invalid value encountered in subtract
#   L_eflux_lo=np.log10((1.+z)*flux*frequency)-np.log10((1.+z)*flux*frequency-e_flux*(1.+z)*frequency)
# ...

# %% [markdown]
# # Running BC03 on South Test Sample
#
# Just running on 3 galaxies from the original test sample
#
# Damien's results are here
#
# https://drive.google.com/drive/folders/1WjLXtSYcWjJT66TqAsd88NR0uOMoEJMO?usp=sharing

# %%
os.chdir("/home/rfinn/research/Virgo/magphys/testingOriginalCode/South/")
# %run ~/github/virgoseds/python/sedFunctions.py

# %%
wavelengths = np.array([ 0.1516,0.2267,0.48623,0.64606,0.91993,3.40025,4.65201,12.81034,22.37528],'d')
s = magphys_sed("2767",wavelengths)
s.plot_sed()
s.plot_histograms()

# %%
wavelengths = np.array([ 0.1516,0.2267,0.48623,0.64606,0.91993,3.40025,4.65201,12.81034,22.37528],'d')
s = magphys_sed("3008",wavelengths)
s.plot_sed()
s.plot_histograms()

# %%
wavelengths = np.array([ 0.1516,0.2267,0.48623,0.64606,0.91993,3.40025,4.65201,12.81034,22.37528],'d')
s = magphys_sed("5229",wavelengths)
s.plot_sed()
s.plot_histograms()
# Out:
# /home/rfinn/github/virgoseds/python/sedFunctions.py:231: RuntimeWarning: invalid value encountered in log10
#   L_eflux_lo=np.log10((1.+z)*flux*frequency)-np.log10((1.+z)*flux*frequency-e_flux*(1.+z)*frequency)

# %% [markdown]
# # Running South data with CB07 code and BC03 libraries
#
# * the original code doesn't give an error with the

# %%
os.chdir("/home/rfinn/research/Virgo/magphys/testingOriginalCode/North-CB07code-BC03libs/")
# %run ~/github/virgoseds/python/sedFunctions.py

# %%
wavelengths = np.array([ 0.1516,0.2267,0.48623,0.64606,0.91993,3.40025,4.65201,12.81034,22.37528],'d')
s = magphys_sed("309",wavelengths)
s.plot_sed()
s.plot_histograms()

# %%
wavelengths = np.array([ 0.1516,0.2267,0.48623,0.64606,0.91993,3.40025,4.65201,12.81034,22.37528],'d')
s = magphys_sed("386",wavelengths)
s.plot_sed()
s.plot_histograms()
# Out:
# /home/rfinn/github/virgoseds/python/sedFunctions.py:229: RuntimeWarning: divide by zero encountered in log10
#   L_flux=np.log10((1.+z)*flux*frequency) # log of nu L_nu
# /home/rfinn/github/virgoseds/python/sedFunctions.py:231: RuntimeWarning: divide by zero encountered in log10
#   L_eflux_lo=np.log10((1.+z)*flux*frequency)-np.log10((1.+z)*flux*frequency-e_flux*(1.+z)*frequency)
# /home/rfinn/github/virgoseds/python/sedFunctions.py:231: RuntimeWarning: invalid value encountered in log10
#   L_eflux_lo=np.log10((1.+z)*flux*frequency)-np.log10((1.+z)*flux*frequency-e_flux*(1.+z)*frequency)
# /home/rfinn/github/virgoseds/python/sedFunctions.py:232: RuntimeWarning: divide by zero encountered in log10
#   L_eflux_hi=-np.log10((1.+z)*flux*frequency)+np.log10((1.+z)*flux*frequency+e_flux*(1.+z)*frequency)
# /home/rfinn/github/virgoseds/python/sedFunctions.py:239: RuntimeWarning: divide by zero encountered in true_divide
#   resid = (10.**L_flux - 10.**L_pflux)/10.**L_flux
# ...

# %%
wavelengths = np.array([ 0.1516,0.2267,0.48623,0.64606,0.91993,3.40025,4.65201,12.81034,22.37528],'d')
s = magphys_sed("473",wavelengths)
s.plot_sed()
s.plot_histograms()

# %% [markdown]
# # Fitting North data with South Filters
#
#
# * not the exact same results as Damien, but probably close enough!

# %%
os.chdir("/home/rfinn/research/Virgo/magphys/testingOriginalCode/North-wSouth-filters/")
# %run ~/github/virgoseds/python/sedFunctions.py

# %%
wavelengths = np.array([ 0.1516,0.2267,0.48623,0.64606,0.91993,3.40025,4.65201,12.81034,22.37528],'d')
s = magphys_sed("309",wavelengths)
s.plot_sed()
s.plot_histograms()

# %%
wavelengths = np.array([ 0.1516,0.2267,0.48623,0.64606,0.91993,3.40025,4.65201,12.81034,22.37528],'d')
s = magphys_sed("386",wavelengths)
s.plot_sed()
s.plot_histograms()
# Out:
# /home/rfinn/github/virgoseds/python/sedFunctions.py:229: RuntimeWarning: divide by zero encountered in log10
#   L_flux=np.log10((1.+z)*flux*frequency) # log of nu L_nu
# /home/rfinn/github/virgoseds/python/sedFunctions.py:231: RuntimeWarning: divide by zero encountered in log10
#   L_eflux_lo=np.log10((1.+z)*flux*frequency)-np.log10((1.+z)*flux*frequency-e_flux*(1.+z)*frequency)
# /home/rfinn/github/virgoseds/python/sedFunctions.py:231: RuntimeWarning: invalid value encountered in log10
#   L_eflux_lo=np.log10((1.+z)*flux*frequency)-np.log10((1.+z)*flux*frequency-e_flux*(1.+z)*frequency)
# /home/rfinn/github/virgoseds/python/sedFunctions.py:232: RuntimeWarning: divide by zero encountered in log10
#   L_eflux_hi=-np.log10((1.+z)*flux*frequency)+np.log10((1.+z)*flux*frequency+e_flux*(1.+z)*frequency)
# /home/rfinn/github/virgoseds/python/sedFunctions.py:239: RuntimeWarning: divide by zero encountered in true_divide
#   resid = (10.**L_flux - 10.**L_pflux)/10.**L_flux
# ...

# %%
wavelengths = np.array([ 0.1516,0.2267,0.48623,0.64606,0.91993,3.40025,4.65201,12.81034,22.37528],'d')
s = magphys_sed("481",wavelengths)
s.plot_sed()
s.plot_histograms()

# %%
os.chdir("/home/rfinn/research/Virgo/magphys/testingOriginalCode/North-wSouth-filters/")
# %run ~/github/virgoseds/python/sedFunctions.py 
wavelengths = np.array([ 0.1516,0.2267,0.48623,0.64606,0.91993,3.40025,4.65201,12.81034,22.37528],'d')
s = magphys_sed("483",wavelengths)
s.plot_sed()
allhist = s.plot_histograms()

# %% [markdown]
# # trying to read in FILTERBIN.RES in python

# %%
ffile = "/home/rfinn/software/magphys-damien/FILTERBIN.RES"

# %%
fbin = open(ffile,'rb')

# %%
for line in fbin:
    print(decode(line))
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-dcde888d9817> in <module>
#       1 for line in fbin:
# ----> 2     print(decode(line))
#       3     break
#
# NameError: name 'decode' is not defined

# %%
import glob

# %%
help(glob.glob)
# Out:
# Help on function glob in module glob:
#
# glob(pathname, *, recursive=False)
#     Return a list of paths matching a pathname pattern.
#
#     The pattern may contain simple shell-style wildcards a la
#     fnmatch. However, unlike fnmatch, filenames starting with a
#     dot are special cases that are not matched by '*' and '?'
#     patterns.
#
#     If recursive is true, the pattern '**' will match any files and
#     zero or more directories and subdirectories.
